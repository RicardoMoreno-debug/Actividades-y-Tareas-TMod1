# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Consideremos la siguiente lista de estados de México.

# %%
Estados = [ "Jalisco", "Puebla", "CDMX", "Nuevo León", "Oaxaca", "Chiapas", "Veracruz", "Yucatán", "Sonora", "Jalisco", "Puebla", "Baja California", "Querétaro", "CDMX" ]

# %%
Estados
# Out:
# ['Jalisco',
#  'Puebla',
#  'CDMX',
#  'Nuevo León',
#  'Oaxaca',
#  'Chiapas',
#  'Veracruz',
#  'Yucatán',
#  'Sonora',
#  'Jalisco',
#  'Puebla',
#  'Baja California',
#  'Querétaro',
#  'CDMX']

# %% [markdown]
# Ordenemos la lista alfabeticamente, usando la función .sort()

# %%
Estados.sort()

# %%
Estados
# Out:
# ['Baja California',
#  'CDMX',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán']

# %% [markdown]
# Lo siguiente por hacer es eliminar los elementos repetidos.

# %%
Estados.pop(1)
# Out:
# 'CDMX'

# %%
Estados
# Out:
# ['Baja California',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán']

# %%
Estados.pop(3)
# Out:
# 'Jalisco'

# %%
Estados
# Out:
# ['Baja California',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán']

# %%
Estados.pop(6)
# Out:
# 'Puebla'

# %%
Estados
# Out:
# ['Baja California',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán']

# %% [markdown]
# Añadimos al inicio de la lista a Aguascalientes

# %%
Estados.insert(0,'Aguascalientes')
Estados
# Out:
# ['Aguascalientes',
#  'Baja California',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán']

# %% [markdown]
# Y añadimos al final de la lista Zacatecas

# %%
Estados.insert(12,'Zacatecas')
Estados
# Out:
# ['Aguascalientes',
#  'Baja California',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán',
#  'Zacatecas']

# %% [markdown]
# Veamos si Oaxaca está en la lista de estados

# %%
'Oaxaca' in Estados
# Out:
# True

# %% [markdown]
# Oaxaca sí está en la lista de estados.

# %% [markdown]
# Por último, imprimimos la lista de estados y su longitud

# %%
Estados
# Out:
# ['Aguascalientes',
#  'Baja California',
#  'CDMX',
#  'Chiapas',
#  'Jalisco',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Querétaro',
#  'Sonora',
#  'Veracruz',
#  'Yucatán',
#  'Zacatecas']

# %%
long = len(Estados)
print("La longitud de la lista de estados es:", long)
# Out:
# La longitud de la lista de estados es: 13
